# %% [markdown]
# # [**Building NLP Content-Based Recommender Systems**](https://medium.com/@armandj.olivares/building-nlp-content-based-recommender-systems-b104a709c042)
#
# - [Github](https://github.com/ArmandDS/jobs_recommendations/blob/master/job_analysis_content_recommendation.ipynb)
# - [Kaggle](https://www.kaggle.com/datasets/kandij/job-recommendation-datasets?resource=download)
#
# A replica and adaptation of Armando Olivares' work.

# %% [markdown]
# ## **Summary**
#
# What was done is, essentially, given **potential employee** information and **job information**, understanding information as text, we try to find the **best job** in for each employee based on the similarity of words employed in both set of information.
#
# Content filtering takes an **item to item** approach, and we are also taking the **employee** information as a possible item, against another item, the job.
#
# For the **potential employee** we looked for:
# 1. Viewed jobs
# 2. Job experience
# 3. Positions of interest
#
# For the **job** we only have position-related data.
#
# We first create a `tfidfVectorizer()` trained and transform with the **job information**, then the same **TFIDF** is applied the the **employee information**, then we look for the most suitable job given the **cosine similarity** between both sets of data.

# %% [markdown]
# **References**
#
# - [Count Vectorizer vs TFIDF Vectorizer | NLP](https://www.linkedin.com/pulse/count-vectorizers-vs-tfidf-natural-language-processing-sheel-saket)
# - [TF-IDF Vectorizer Scikit-Learn](https://medium.com/@cmukesh8688/tf-idf-vectorizer-scikit-learn-dbc0244a911a)

# %%
import pandas as pd
pd.options.display.max_columns = 100
pd.options.display.max_rows = 100
pd.options.display.max_colwidth = 120


import numpy as np
import nltk
import warnings; warnings.filterwarnings('ignore')
import textwrap

# %% [markdown]
# ## **Load the data**

# %%
df_jobs = pd.read_csv('archive/Combined_Jobs_Final.csv')
display(df_jobs.head())
df_jobs.info()
# Out:
#    Job.ID  Provider Status  \
# 0     111         1   open
# 1     113         1   open
# 2     117         1   open
# 3     121         1   open
# 4     127         1   open
#
#                                                      Slug  \
# 0                         palo-alto-ca-tacolicious-server
# 1         san-francisco-ca-claude-lane-kitchen-staff-chef
# 2      san-francisco-ca-machka-restaurants-corp-bartender
# 3                       brisbane-ca-teriyaki-house-server
# 4  los-angeles-ca-rosa-mexicano-sunset-kitchen-staff-chef
#
#                                          Title            Position  \
# 0                         Server @ Tacolicious              Server
# 1             Kitchen Staff/Chef @ Claude Lane  Kitchen Staff/Chef
# 2         Bartender @ Machka Restaurants Corp.           Bartender
# 3                      Server @ Teriyaki House              Server
# 4  Kitchen Staff/Chef @ Rosa Mexicano - Sunset  Kitchen Staff/Chef
#
#                     Company           City  State.Name State.Code Address  \
# 0               Tacolicious      Palo Alto  California         CA     NaN
# 1               Claude Lane  San Francisco  California         CA     NaN
# 2  Machka Restaurants Corp.  San Francisco  California         CA     NaN
# 3            Teriyaki House       Brisbane  California         CA     NaN
# 4    Rosa Mexicano - Sunset    Los Angeles  California         CA     NaN
#
#     Latitude   Longitude            Industry  \
# 0  37.443346 -122.161170  Food and Beverages
# 1  37.789830 -122.404268  Food and Beverages
# 2  37.795597 -122.402963  Food and Beverages
# 3  37.685073 -122.400275  Food and Beverages
# 4  34.073384 -118.460439  Food and Beverages
#
#                                                                                                            Job.Description  \
# 0  Tacolicious' first Palo Alto store just opened recently, and we are hiring! If you love tacos, you will love working...
# 1   \r\n\r\nNew French Brasserie in S.F. Financial District Seeks Chef\r\nWe are seeking an energetic, dynamic chef to ...
# 2  We are a popular Mediterranean wine bar and restaurant in Financial District.\r\n\r\nWe are looking for an experienc...
# 3   ● Serve food/drinks to customers in a professional manner \r\n ● Act as a cashier when needed \r\n ● Clean up the d...
# 4  Located at the heart of Hollywood, we are one of the most popular Mexican places in LA! We are currently looking for...
#
#    Requirements  Salary Listing.Start Listing.End Employment.Type  \
# 0           NaN    8.00           NaN         NaN       Part-Time
# 1           NaN    0.00           NaN         NaN       Part-Time
# 2           NaN   11.00           NaN         NaN       Part-Time
# 3           NaN   10.55           NaN         NaN       Part-Time
# 4           NaN   10.55           NaN         NaN       Part-Time
#
#   Education.Required               Created.At               Updated.At
# 0                NaN  2013-03-12 02:08:28 UTC  2014-08-16 15:35:36 UTC
# 1                NaN  2013-04-12 08:36:36 UTC  2014-08-16 15:35:36 UTC
# 2                NaN  2013-07-16 09:34:10 UTC  2014-08-16 15:35:37 UTC
# 3                NaN  2013-09-04 15:40:30 UTC  2014-08-16 15:35:38 UTC
# 4                NaN  2013-07-17 15:26:18 UTC  2014-08-16 15:35:40 UTC
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84090 entries, 0 to 84089
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Job.ID              84090 non-null  int64
#  1   Provider            84090 non-null  int64
#  2   Status              84090 non-null  object
#  3   Slug                84090 non-null  object
#  4   Title               84090 non-null  object
#  5   Position            84090 non-null  object
#  6   Company             81819 non-null  object
#  7   City                83955 non-null  object
#  8   State.Name          83919 non-null  object
#  9   State.Code          83919 non-null  object
#  10  Address             36 non-null     object
#  11  Latitude            84090 non-null  float64
#  12  Longitude           84090 non-null  float64
#  13  Industry            267 non-null    object
#  14  Job.Description     84034 non-null  object
#  15  Requirements        0 non-null      float64
#  16  Salary              229 non-null    float64
#  17  Listing.Start       83407 non-null  object
#  18  Listing.End         83923 non-null  object
#  19  Employment.Type     84080 non-null  object
#  20  Education.Required  83823 non-null  object
#  21  Created.At          84090 non-null  object
#  22  Updated.At          84090 non-null  object
# dtypes: float64(4), int64(2), object(17)
# memory usage: 14.8+ MB

# %% [markdown]
# Selecting the columns for the jobs corpus

# %%
# Select the columns and give them format
cols = ['Job.ID', 'Title', 'Position', 'Company', 'City', 'Employment.Type', 'Job.Description']
df_jobs = df_jobs[cols]
df_jobs.columns = [col.replace('.', '_') for col in df_jobs.columns]
df_jobs.head()
# Out:
#    Job_ID                                        Title            Position  \
# 0     111                         Server @ Tacolicious              Server
# 1     113             Kitchen Staff/Chef @ Claude Lane  Kitchen Staff/Chef
# 2     117         Bartender @ Machka Restaurants Corp.           Bartender
# 3     121                      Server @ Teriyaki House              Server
# 4     127  Kitchen Staff/Chef @ Rosa Mexicano - Sunset  Kitchen Staff/Chef
#
#                     Company           City Employment_Type  \
# 0               Tacolicious      Palo Alto       Part-Time
# 1               Claude Lane  San Francisco       Part-Time
# 2  Machka Restaurants Corp.  San Francisco       Part-Time
# 3            Teriyaki House       Brisbane       Part-Time
# 4    Rosa Mexicano - Sunset    Los Angeles       Part-Time
#
#                                                                                                            Job_Description
# 0  Tacolicious' first Palo Alto store just opened recently, and we are hiring! If you love tacos, you will love working...
# 1   \r\n\r\nNew French Brasserie in S.F. Financial District Seeks Chef\r\nWe are seeking an energetic, dynamic chef to ...
# 2  We are a popular Mediterranean wine bar and restaurant in Financial District.\r\n\r\nWe are looking for an experienc...
# 3   ● Serve food/drinks to customers in a professional manner \r\n ● Act as a cashier when needed \r\n ● Clean up the d...
# 4  Located at the heart of Hollywood, we are one of the most popular Mexican places in LA! We are currently looking for...

# %%
# checking for the null values
df_jobs.isnull().sum()
# Out:
# Job_ID                0
# Title                 0
# Position              0
# Company            2271
# City                135
# Employment_Type      10
# Job_Description      56
# dtype: int64

# %% [markdown]
# We see that there are only 9 companies cities that are having `NaN` values so it must be manually addig their head quarters (by simply searching at google).

# %%
# Set a list of tuples with company-actual city
job_city = [
    ('CHI Payment Systems', 'Illinois'),
    ('Academic Year In America', 'Stanford'),
    ('CBS Healthcare Services and Staffing ', 'Urbandale'),
    ('Driveline Retail', 'Coppell'),
    ('Educational Testing Services', 'New Jersey'),
    ('Genesis Health System', 'Davennport'),
    ('Home Instead Senior Care', 'Nebraska'),
    ('St. Francis Hospital', 'New York'),
    ('Volvo Group', 'Washington'),
    ('CBS Healthcare Services and Staffing', 'Urbandale')
]

for company, city in job_city:
    df_jobs.loc[df_jobs['Company'] == company, 'City'] = city

# %%
# Look again for missing cities
df_jobs.isnull().sum()
# Out:
# Job_ID                0
# Title                 0
# Position              0
# Company            2271
# City                  2
# Employment_Type      10
# Job_Description      56
# dtype: int64

# %%
# There are e,ployment type NA for uber, so asume that is Flexible
df_jobs[df_jobs['Employment_Type'].isnull()]
# Out:
#        Job_ID                   Title         Position Company           City  \
# 10768  153197  Driving Partner @ Uber  Driving Partner    Uber  San Francisco
# 10769  153198  Driving Partner @ Uber  Driving Partner    Uber    Los Angeles
# 10770  153199  Driving Partner @ Uber  Driving Partner    Uber        Chicago
# 10771  153200  Driving Partner @ Uber  Driving Partner    Uber         Boston
# 10772  153201  Driving Partner @ Uber  Driving Partner    Uber      Ann Arbor
# 10773  153202  Driving Partner @ Uber  Driving Partner    Uber       Oklahoma
# 10774  153203  Driving Partner @ Uber  Driving Partner    Uber          Omaha
# 10775  153204  Driving Partner @ Uber  Driving Partner    Uber        Lincoln
# 10776  153205  Driving Partner @ Uber  Driving Partner    Uber    Minneapolis
# 10777  153206  Driving Partner @ Uber  Driving Partner    Uber       St. Paul
#
#       Employment_Type  \
# 10768             NaN
# 10769             NaN
# 10770             NaN
# 10771             NaN
# 10772             NaN
# 10773             NaN
# 10774             NaN
# 10775             NaN
# 10776             NaN
# 10777             NaN
#
#                                                                                                                Job_Description
# 10768  Uber is changing the way the world moves. From the tap of a button, Uber connects riders with drivers to make reliab...
# 10769  Uber is changing the way the world moves. From the tap of a button, Uber connects riders with drivers to make reliab...
# 10770  Uber is changing the way the world moves. From the tap of a button, Uber connects riders with drivers to make reliab...
# 10771  Uber is changing the way the world moves. From the tap of a button, Uber connects riders with drivers to make reliab...
# 10772  Uber is changing the way the world moves. From the tap of a button, Uber connects riders with drivers to make reliab...
# 10773  Uber is changing the way the world moves. From the tap of a button, Uber connects riders with drivers to make reliab...
# 10774  Uber is changing the way the world moves. From the tap of a button, Uber connects riders with drivers to make reliab...
# 10775  Uber is changing the way the world moves. From the tap of a button, Uber connects riders with drivers to make reliab...
# 10776  Uber is changing the way the world moves. From the tap of a button, Uber connects riders with drivers to make reliab...
# 10777  Uber is changing the way the world moves. From the tap of a button, Uber connects riders with drivers to make reliab...

# %%
# Replace missing values for Employment type with 'flexible'
df_jobs['Employment_Type'] = df_jobs['Employment_Type'].fillna('Flexible')

# %% [markdown]
# ## **Creating the job corpus**

# %%
# Add the corpus column, which sums all text attributes into a single column
df_jobs['corpus'] = df_jobs.apply(lambda job: ' '.join([str(job[col]) for col in ['Position', 'Company', 'City', 'Employment_Type', 'Job_Description']]), axis=1)
df_jobs.head()
# Out:
#    Job_ID                                        Title            Position  \
# 0     111                         Server @ Tacolicious              Server
# 1     113             Kitchen Staff/Chef @ Claude Lane  Kitchen Staff/Chef
# 2     117         Bartender @ Machka Restaurants Corp.           Bartender
# 3     121                      Server @ Teriyaki House              Server
# 4     127  Kitchen Staff/Chef @ Rosa Mexicano - Sunset  Kitchen Staff/Chef
#
#                     Company           City Employment_Type  \
# 0               Tacolicious      Palo Alto       Part-Time
# 1               Claude Lane  San Francisco       Part-Time
# 2  Machka Restaurants Corp.  San Francisco       Part-Time
# 3            Teriyaki House       Brisbane       Part-Time
# 4    Rosa Mexicano - Sunset    Los Angeles       Part-Time
#
#                                                                                                            Job_Description  \
# 0  Tacolicious' first Palo Alto store just opened recently, and we are hiring! If you love tacos, you will love working...
# 1   \r\n\r\nNew French Brasserie in S.F. Financial District Seeks Chef\r\nWe are seeking an energetic, dynamic chef to ...
# 2  We are a popular Mediterranean wine bar and restaurant in Financial District.\r\n\r\nWe are looking for an experienc...
# 3   ● Serve food/drinks to customers in a professional manner \r\n ● Act as a cashier when needed \r\n ● Clean up the d...
# 4  Located at the heart of Hollywood, we are one of the most popular Mexican places in LA! We are currently looking for...
#
#                                                                                                                     corpus
# 0  Server Tacolicious Palo Alto Part-Time Tacolicious' first Palo Alto store just opened recently, and we are hiring! I...
# 1  Kitchen Staff/Chef Claude Lane San Francisco Part-Time  \r\n\r\nNew French Brasserie in S.F. Financial District Seek...
# 2  Bartender Machka Restaurants Corp. San Francisco Part-Time We are a popular Mediterranean wine bar and restaurant in...
# 3  Server Teriyaki House Brisbane Part-Time  ● Serve food/drinks to customers in a professional manner \r\n ● Act as a ...
# 4  Kitchen Staff/Chef Rosa Mexicano - Sunset Los Angeles Part-Time Located at the heart of Hollywood, we are one of the...

# %%
# Create a more compact version of the jobs df
df_jobs = df_jobs[['Job_ID', 'Title', 'corpus']].fillna('')
df_jobs.info()
df_jobs.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84090 entries, 0 to 84089
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Job_ID  84090 non-null  int64
#  1   Title   84090 non-null  object
#  2   corpus  84090 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.9+ MB
#    Job_ID                                        Title  \
# 0     111                         Server @ Tacolicious
# 1     113             Kitchen Staff/Chef @ Claude Lane
# 2     117         Bartender @ Machka Restaurants Corp.
# 3     121                      Server @ Teriyaki House
# 4     127  Kitchen Staff/Chef @ Rosa Mexicano - Sunset
#
#                                                                                                                     corpus
# 0  Server Tacolicious Palo Alto Part-Time Tacolicious' first Palo Alto store just opened recently, and we are hiring! I...
# 1  Kitchen Staff/Chef Claude Lane San Francisco Part-Time  \r\n\r\nNew French Brasserie in S.F. Financial District Seek...
# 2  Bartender Machka Restaurants Corp. San Francisco Part-Time We are a popular Mediterranean wine bar and restaurant in...
# 3  Server Teriyaki House Brisbane Part-Time  ● Serve food/drinks to customers in a professional manner \r\n ● Act as a ...
# 4  Kitchen Staff/Chef Rosa Mexicano - Sunset Los Angeles Part-Time Located at the heart of Hollywood, we are one of the...

# %%
# Download needed functions from NLTK
# nltk.download(['punkt', 'stopwords', 'wordnet', 'averaged_perceptron_tagger'])

# %% [markdown]
# ### **NLP approach for content filtering**

# %%
from nltk.corpus import stopwords
import re
import string
from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize
wn = WordNetLemmatizer()

# %%
# Set a set of english stopwords
STOPWORDS = set(stopwords.words('english'))

def is_valid_token(token):
    """
    Validate tokens, they must:

    1. Not be a stopword (and, the, to, of...)
    2. Not be punctuation (!, ?, ., ...)
    3. Not be a single letter
    """
    return token not in STOPWORDS and token not in string.punctuation and len(token) > 2


def clean_text(text):
    # Drop single quotes
    text = re.sub('\'', '', text)
    # Convert numbers or any non-word character into white spaces
    text = re.sub('(\\d|\\W)+', ' ', text)
    # Replace semi-stopword from HTML
    text = text.replace('nbsp', '')
    
    # Return the clean text by 1) tokenizing the text, and 2) extracting the stem of word
    # if it is a valid token. Stem verbs only.
    clean_text = [word for word in 
                  [wn.lemmatize(word, pos='v') for word in word_tokenize(text.lower()) if is_valid_token(word)]
                  if is_valid_token(word)
    ]
    
    
    return ' '.join(clean_text)

# %%
# Now having functions that tokenizes words, cleans tokens, removes unnecesary ones and
# stems, then apply it to the corpus
df_jobs['corpus'] = df_jobs['corpus'].apply(clean_text)
df_jobs.head()
# Out:
#    Job_ID                                        Title  \
# 0     111                         Server @ Tacolicious
# 1     113             Kitchen Staff/Chef @ Claude Lane
# 2     117         Bartender @ Machka Restaurants Corp.
# 3     121                      Server @ Teriyaki House
# 4     127  Kitchen Staff/Chef @ Rosa Mexicano - Sunset
#
#                                                                                                                     corpus
# 0  server tacolicious palo alto part time tacolicious first palo alto store open recently hire love tacos love work res...
# 1  kitchen staff chef claude lane san francisco part time new french brasserie financial district seek chef seek energe...
# 2  bartender machka restaurants corp san francisco part time popular mediterranean wine bar restaurant financial distri...
# 3  server teriyaki house brisbane part time serve food drink customers professional manner act cashier need clean din s...
# 4  kitchen staff chef rosa mexicano sunset los angeles part time locate heart hollywood one popular mexican place curre...

# %% [markdown]
# ### **TF-IDF (Term Frequency Inverse Document Frequency)**

# %%
# intialize tfidif vectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Initializing tfidf vectorizer
tfidf_vectorizer = TfidfVectorizer()

# Create a vectorization approach of the job corpus
tfidf_jobid = tfidf_vectorizer.fit_transform(df_jobs['corpus'])
tfidf_jobid
# Out:
# <84090x51498 sparse matrix of type '<class 'numpy.float64'>'
# 	with 8488642 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## **Creating the User Corpus**

# %% [markdown]
# ### **Viewed jobs**

# %%
df_job_view = pd.read_csv('archive/Job_Views.csv')
df_job_view.head()
# Out:
#    Applicant.ID  Job.ID  \
# 0         10000   73666
# 1         10000   96655
# 2         10001   84141
# 3         10002   77989
# 4         10002   69568
#
#                                                                                     Title  \
# 0                                                   Cashiers & Valets Needed! @ WallyPark
# 1  Macy's Seasonal Retail Fragrance Cashier  - Garden City, NY - Roosevelt Field @ Macy's
# 2                            Part Time Showroom Sales / Cashier @ Grizzly Industrial Inc.
# 3                                Event Specialist Part Time @ Advantage Sales & Marketing
# 4                                               Bonefish - Kitchen Staff @ Bonefish Grill
#
#                                                                         Position  \
# 0                                                      Cashiers & Valets Needed!
# 1  Macy's Seasonal Retail Fragrance Cashier  - Garden City, NY - Roosevelt Field
# 2                                             Part Time Showroom Sales / Cashier
# 3                                                     Event Specialist Part Time
# 4                                                       Bonefish - Kitchen Staff
#
#                        Company          City      State.Name State.Code  \
# 0                    WallyPark        Newark      New Jersey         NJ
# 1                       Macy's   Garden City        New York         NY
# 2      Grizzly Industrial Inc.    Bellingham      Washington         WA
# 3  Advantage Sales & Marketing  Simpsonville  South Carolina         SC
# 4               Bonefish Grill    Greenville  South Carolina         SC
#
#   Industry               View.Start                 View.End  View.Duration  \
# 0      NaN  2014-12-12 20:12:35 UTC  2014-12-12 20:31:24 UTC         1129.0
# 1      NaN  2014-12-12 20:08:50 UTC  2014-12-12 20:10:15 UTC           84.0
# 2      NaN  2014-12-12 20:12:32 UTC  2014-12-12 20:17:18 UTC          286.0
# 3      NaN  2014-12-12 20:39:23 UTC  2014-12-12 20:42:13 UTC          170.0
# 4      NaN  2014-12-12 20:43:25 UTC  2014-12-12 20:43:58 UTC           33.0
#
#                 Created.At               Updated.At
# 0  2014-12-12 20:12:35 UTC  2014-12-12 20:12:35 UTC
# 1  2014-12-12 20:08:50 UTC  2014-12-12 20:08:50 UTC
# 2  2014-12-12 20:12:32 UTC  2014-12-12 20:12:32 UTC
# 3  2014-12-12 20:39:23 UTC  2014-12-12 20:39:23 UTC
# 4  2014-12-12 20:43:25 UTC  2014-12-12 20:43:25 UTC

# %% [markdown]
# Reduce the number of features for the current dataframe

# %%
df_job_view = df_job_view[['Applicant.ID', 'Job.ID', 'Position', 'Company', 'City']]
df_job_view.columns = [col.replace('.', '_') for col in df_job_view.columns]
df_job_view.head()
# Out:
#    Applicant_ID  Job_ID  \
# 0         10000   73666
# 1         10000   96655
# 2         10001   84141
# 3         10002   77989
# 4         10002   69568
#
#                                                                         Position  \
# 0                                                      Cashiers & Valets Needed!
# 1  Macy's Seasonal Retail Fragrance Cashier  - Garden City, NY - Roosevelt Field
# 2                                             Part Time Showroom Sales / Cashier
# 3                                                     Event Specialist Part Time
# 4                                                       Bonefish - Kitchen Staff
#
#                        Company          City
# 0                    WallyPark        Newark
# 1                       Macy's   Garden City
# 2      Grizzly Industrial Inc.    Bellingham
# 3  Advantage Sales & Marketing  Simpsonville
# 4               Bonefish Grill    Greenville

# %%
# look for nulls
df_job_view.isnull().sum()
# Out:
# Applicant_ID      0
# Job_ID            0
# Position          0
# Company         580
# City              0
# dtype: int64

# %%
# Transform the features into a single column
df_job_view['corpus'] = df_job_view.apply(lambda job_view: ' '.join([str(job_view[col]) for col in ['Position', 'Company', 'City']]), axis=1) \
                                    .apply(clean_text)

df_job_view = df_job_view[['Applicant_ID', 'corpus']]
df_job_view.info()
df_job_view.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12370 entries, 0 to 12369
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Applicant_ID  12370 non-null  int64
#  1   corpus        12370 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 193.4+ KB
#    Applicant_ID  \
# 0         10000
# 1         10000
# 2         10001
# 3         10002
# 4         10002
#
#                                                                                   corpus
# 0                                                    cashier valet need wallypark newark
# 1  macys seasonal retail fragrance cashier garden city roosevelt field macys garden city
# 2                     part time showroom sales cashier grizzly industrial inc bellingham
# 3                         event specialist part time advantage sales market simpsonville
# 4                                       bonefish kitchen staff bonefish grill greenville

# %%
# Are there any Applicants with multiple viewed jobs?
df_job_view.groupby('Applicant_ID').count().sort_values('corpus', ascending=False)
# Out:
#               corpus
# Applicant_ID
# 601               75
# 6808              61
# 11475             56
# 6945              44
# 9137              43
# ...              ...
# 12368              1
# 12364              1
# 9273               1
# 9279               1
# 11388              1
#
# [3448 rows x 1 columns]

# %%
# Combine all viewed corpus into a single corpus per Applicant
df_job_view = df_job_view.groupby('Applicant_ID')['corpus'].apply(' '.join).reset_index()
df_job_view.info()
df_job_view.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3448 entries, 0 to 3447
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Applicant_ID  3448 non-null   int64
#  1   corpus        3448 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 54.0+ KB
#    Applicant_ID  \
# 0            42
# 1            96
# 2           153
# 3           601
# 4          1877
#
#                                                                                                                     corpus
# 0  movie extras actors model want san francisco part time full time cast san francisco grand open new location entry le...
# 1                     kitchen staff izakaya yuzuki san francisco server waraku san francisco server sakae sushi burlingame
# 2  valic financial advisor intern roseville aig corp roseville travel inventory associate wis international citrus heig...
# 3  retail sales consultant retail bay area associate manager tumi inc san francisco toy express seasonal store supervis...
# 4                                                                                      sales associate see candy sunnyvale

# %%
# look for unique ids
df_job_view['Applicant_ID'].nunique()
# Out:
# 3448

# %% [markdown]
# ### **Experience Dataset**

# %%
df_experience = pd.read_csv('archive/Experience.csv')
df_experience.info()
df_experience.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8653 entries, 0 to 8652
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Applicant.ID          8653 non-null   int64
#  1   Position.Name         7655 non-null   object
#  2   Employer.Name         8568 non-null   object
#  3   City                  4891 non-null   object
#  4   State.Name            4595 non-null   object
#  5   State.Code            4595 non-null   object
#  6   Start.Date            6618 non-null   object
#  7   End.Date              4906 non-null   object
#  8   Job.Description       5646 non-null   object
#  9   Salary                2798 non-null   float64
#  10  Can.Contact.Employer  3581 non-null   object
#  11  Created.At            8653 non-null   object
#  12  Updated.At            8653 non-null   object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 878.9+ KB
#    Applicant.ID                                               Position.Name  \
# 0         10001  Account Manager / Sales Administration / Quality Assurance
# 1         10001             Electronics Technician / Item Master Controller
# 2         10001                                            Machine Operator
# 3         10003                                      maintenance technician
# 4         10003                                          Electrical Helper
#
#                Employer.Name         City            State.Name State.Code  \
# 0         Barcode Resourcing   Bellingham            Washington         WA
# 1                Ryzex Group   Bellingham            Washington         WA
# 2                comptec inc       Custer            Washington         WA
# 3           Winn residental    washington  District of Columbia         DC
# 4  michael and son services   alexandria               Virginia         VA
#
#    Start.Date    End.Date  \
# 0  2012-10-15         NaN
# 1  2001-12-01  2012-04-01
# 2  1997-01-01  1999-01-01
# 3         NaN         NaN
# 4         NaN         NaN
#
#                                                       Job.Description  Salary  \
# 0                                                                 NaN     NaN
# 1                                                                 NaN     NaN
# 2                                                                 NaN     NaN
# 3  Necessary maintenance for "Make Ready" Plumbing, electrical, HvAc     10.0
# 4                     repair and services of electrical construction      NaN
#
#   Can.Contact.Employer               Created.At               Updated.At
# 0                  NaN  2014-12-12 20:10:02 UTC  2014-12-12 20:10:02 UTC
# 1                  NaN  2014-12-12 20:10:02 UTC  2014-12-12 20:10:02 UTC
# 2                  NaN  2014-12-12 20:10:02 UTC  2014-12-12 20:10:02 UTC
# 3                False  2014-12-12 21:27:05 UTC  2014-12-12 21:27:05 UTC
# 4                False  2014-12-12 21:27:05 UTC  2014-12-12 21:27:05 UTC

# %%
# Take columns of interest
df_experience = df_experience[['Applicant.ID', 'Position.Name', 'Employer.Name', 'City', 'Job.Description']].fillna('')
df_experience.columns = [col.replace('.', '_') for col in df_experience.columns]
df_experience.info()
df_experience.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8653 entries, 0 to 8652
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Applicant_ID     8653 non-null   int64
#  1   Position_Name    8653 non-null   object
#  2   Employer_Name    8653 non-null   object
#  3   City             8653 non-null   object
#  4   Job_Description  8653 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 338.1+ KB
#    Applicant_ID                                               Position_Name  \
# 0         10001  Account Manager / Sales Administration / Quality Assurance
# 1         10001             Electronics Technician / Item Master Controller
# 2         10001                                            Machine Operator
# 3         10003                                      maintenance technician
# 4         10003                                          Electrical Helper
#
#                Employer_Name         City  \
# 0         Barcode Resourcing   Bellingham
# 1                Ryzex Group   Bellingham
# 2                comptec inc       Custer
# 3           Winn residental    washington
# 4  michael and son services   alexandria
#
#                                                       Job_Description
# 0
# 1
# 2
# 3  Necessary maintenance for "Make Ready" Plumbing, electrical, HvAc
# 4                     repair and services of electrical construction

# %%
# Get the corpus of the job experience
df_experience['corpus'] = df_experience.apply(lambda job_experience: ' '.join([str(job_experience[col]) for col in ['Position_Name', 'Employer_Name', 'City', 'Job_Description']]), axis=1) \
                                        .apply(clean_text)

df_experience = df_experience[['Applicant_ID', 'corpus']]
df_experience.info()
df_experience.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8653 entries, 0 to 8652
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Applicant_ID  8653 non-null   int64
#  1   corpus        8653 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 135.3+ KB
#    Applicant_ID  \
# 0         10001
# 1         10001
# 2         10001
# 3         10003
# 4         10003
#
#                                                                                                      corpus
# 0                      account manager sales administration quality assurance barcode resourcing bellingham
# 1                                      electronics technician item master controller ryzex group bellingham
# 2                                                                       machine operator comptec inc custer
# 3  maintenance technician winn residental washington necessary maintenance make ready plumb electrical hvac
# 4                   electrical helper michael son service alexandria repair service electrical construction

# %%
# Are there any applicants with multiple experience? The desired is yes
df_experience.groupby('Applicant_ID').count().sort_values('corpus', ascending=False)
# Out:
#               corpus
# Applicant_ID
# 7606              24
# 5241              22
# 14149             18
# 14347             18
# 8798              17
# ...              ...
# 2792               1
# 7699               1
# 7685               1
# 4890               1
# 4436               1
#
# [3790 rows x 1 columns]

# %%
# Aggregate all the available info into a single record
df_experience = df_experience.groupby('Applicant_ID')['corpus'].apply(' '.join).reset_index()
df_experience.info()
df_experience.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3790 entries, 0 to 3789
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Applicant_ID  3790 non-null   int64
#  1   corpus        3790 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 59.3+ KB
#    Applicant_ID  \
# 0             2
# 1             3
# 2             6
# 3             8
# 4            11
#
#                                                                                                                     corpus
# 0  writer uloop blog cecilia abate san francisco write article uloop blog site mostly read students school within unite...
# 1      prep cook moscone center san francisco server aloha beach resort shenzhen china market intern honda guangzhou china
# 2                                                                                      project assistant iom nairobi kenya
# 3                                                 deli clerk server cashier food prep order taker safeway grocery inc lodi
# 4                                                                                         cashier cristina green daly city

# %%
# Get unique Applicant_ID counts
df_experience['Applicant_ID'].nunique()
# Out:
# 3790

# %% [markdown]
# ### **Positions of Interest**

# %%
df_poi = pd.read_csv('Archive/Positions_Of_Interest.csv')
df_poi.columns = [col.replace('.', '_') for col in df_poi.columns]
df_poi.info()
df_poi.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6560 entries, 0 to 6559
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Applicant_ID          6560 non-null   int64
#  1   Position_Of_Interest  6558 non-null   object
#  2   Created_At            6560 non-null   object
#  3   Updated_At            6560 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 205.1+ KB
#    Applicant_ID Position_Of_Interest               Created_At  \
# 0         10003     security officer  2014-12-12 21:20:54 UTC
# 1         10007               Server  2014-08-14 15:56:42 UTC
# 2         10007            Bartender  2014-08-14 15:56:44 UTC
# 3         10008                 Host  2014-08-14 15:56:42 UTC
# 4         10008              Barista  2014-08-14 15:56:43 UTC
#
#                 Updated_At
# 0  2014-12-12 21:20:54 UTC
# 1  2015-02-26 20:35:12 UTC
# 2  2015-02-19 23:21:28 UTC
# 3  2015-02-26 20:35:12 UTC
# 4  2015-02-18 02:35:06 UTC

# %%
# Drop unnecesary columns and give format to the corpus
df_poi = df_poi[['Applicant_ID', 'Position_Of_Interest']].rename(columns={'Position_Of_Interest':'corpus'})
df_poi['corpus'] = df_poi['corpus'].map(str).apply(clean_text)
df_poi.info()
df_poi.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6560 entries, 0 to 6559
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Applicant_ID  6560 non-null   int64
#  1   corpus        6560 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 102.6+ KB
#    Applicant_ID            corpus
# 0         10003  security officer
# 1         10007            server
# 2         10007         bartender
# 3         10008              host
# 4         10008           barista

# %%
# Are there any Applicants with multiple POIs?
df_poi.groupby('Applicant_ID').count().sort_values('corpus', ascending=False)
# Out:
#               corpus
# Applicant_ID
# 2254              13
# 3719              13
# 7528              13
# 7101              13
# 7902              11
# ...              ...
# 5873               1
# 5931               1
# 5989               1
# 5991               1
# 14546              1
#
# [2068 rows x 1 columns]

# %%
# Then combine records into a single record per Applicant
df_poi = df_poi.groupby('Applicant_ID')['corpus'].apply(' '.join).reset_index()
df_poi.info()
df_poi.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2068 entries, 0 to 2067
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Applicant_ID  2068 non-null   int64
#  1   corpus        2068 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 32.4+ KB
#    Applicant_ID  \
# 0            96
# 1           153
# 2           256
# 3           438
# 4           568
#
#                                                                                 corpus
# 0                                                                               server
# 1                                   server host barista customer service rep sales rep
# 2  server host receptionist book keeper customer service rep sales rep production area
# 3                                             server host barista customer service rep
# 4                                        receptionist book keeper customer service rep

# %% [markdown]
# ### **Create the final user datast**

# %%
# First join viewed jobs with experience
jobs_view_exp = df_job_view.merge(df_experience, on='Applicant_ID', how='outer', suffixes=['_view', '_experience']).fillna('')
jobs_view_exp.info()
jobs_view_exp.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6461 entries, 0 to 6460
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Applicant_ID       6461 non-null   int64
#  1   corpus_view        6461 non-null   object
#  2   corpus_experience  6461 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 151.6+ KB
#    Applicant_ID  \
# 0            42
# 1            96
# 2           153
# 3           601
# 4          1877
#
#                                                                                                                corpus_view  \
# 0  movie extras actors model want san francisco part time full time cast san francisco grand open new location entry le...
# 1                     kitchen staff izakaya yuzuki san francisco server waraku san francisco server sakae sushi burlingame
# 2  valic financial advisor intern roseville aig corp roseville travel inventory associate wis international citrus heig...
# 3  retail sales consultant retail bay area associate manager tumi inc san francisco toy express seasonal store supervis...
# 4                                                                                      sales associate see candy sunnyvale
#
#                                                                                                          corpus_experience
# 0                                                  street marketer media nation fairfield courtesy clerk safeway fairfield
# 1  cashier honey berry san francisco greet people introduce recommend food items menu take order pos phone take clean t...
# 2  photographer brand affinity technologies santa clara capture memories experience families group individuals provide ...
# 3
# 4  registration coordinator wellness corporate solutions bethesda greet people help fill paperwork front desk extern in...

# %% [markdown]
# Now merge the positions of interest - dataframe

# %%
jobs_view_exp_poi = jobs_view_exp.merge(df_poi, on='Applicant_ID', how='outer').fillna('') \
                                .rename(columns={'corpus':'corpus_poi'})
jobs_view_exp_poi.info()
jobs_view_exp_poi.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7037 entries, 0 to 7036
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Applicant_ID       7037 non-null   int64
#  1   corpus_view        7037 non-null   object
#  2   corpus_experience  7037 non-null   object
#  3   corpus_poi         7037 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 220.0+ KB
#    Applicant_ID  \
# 0            42
# 1            96
# 2           153
# 3           601
# 4          1877
#
#                                                                                                                corpus_view  \
# 0  movie extras actors model want san francisco part time full time cast san francisco grand open new location entry le...
# 1                     kitchen staff izakaya yuzuki san francisco server waraku san francisco server sakae sushi burlingame
# 2  valic financial advisor intern roseville aig corp roseville travel inventory associate wis international citrus heig...
# 3  retail sales consultant retail bay area associate manager tumi inc san francisco toy express seasonal store supervis...
# 4                                                                                      sales associate see candy sunnyvale
#
#                                                                                                          corpus_experience  \
# 0                                                  street marketer media nation fairfield courtesy clerk safeway fairfield
# 1  cashier honey berry san francisco greet people introduce recommend food items menu take order pos phone take clean t...
# 2  photographer brand affinity technologies santa clara capture memories experience families group individuals provide ...
# 3
# 4  registration coordinator wellness corporate solutions bethesda greet people help fill paperwork front desk extern in...
#
#                                            corpus_poi
# 0
# 1                                              server
# 2  server host barista customer service rep sales rep
# 3               server line cook customer service rep
# 4                                        receptionist

# %%
# Get unique number of Applicants
jobs_view_exp_poi['Applicant_ID'].nunique()
# Out:
# 7037

# %% [markdown]
# Combine all features into a single one

# %%
applicants = jobs_view_exp_poi.copy()
applicants['corpus'] = applicants.apply(lambda employee: ' '.join([employee[col] for col in ['corpus_view', 'corpus_experience', 'corpus_poi']]), axis=1)
applicants = applicants[['Applicant_ID', 'corpus']].sort_values('Applicant_ID')

applicants.info()
applicants.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7037 entries, 3448 to 6460
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Applicant_ID  7037 non-null   int64
#  1   corpus        7037 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 164.9+ KB
#       Applicant_ID  \
# 3448             2
# 3449             3
# 3450             6
# 3451             8
# 3452            11
#
#                                                                                                                        corpus
# 3448   writer uloop blog cecilia abate san francisco write article uloop blog site mostly read students school within unit...
# 3449     prep cook moscone center san francisco server aloha beach resort shenzhen china market intern honda guangzhou china
# 3450                                                                                     project assistant iom nairobi kenya
# 3451                                                deli clerk server cashier food prep order taker safeway grocery inc lodi
# 3452                                                                                        cashier cristina green daly city

# %%
# Reset the index in order to have an ordered index beased on the new information
applicants = applicants.reset_index().drop('index', axis=1)
applicants.head()
# Out:
#    Applicant_ID  \
# 0             2
# 1             3
# 2             6
# 3             8
# 4            11
#
#                                                                                                                     corpus
# 0   writer uloop blog cecilia abate san francisco write article uloop blog site mostly read students school within unit...
# 1     prep cook moscone center san francisco server aloha beach resort shenzhen china market intern honda guangzhou china
# 2                                                                                     project assistant iom nairobi kenya
# 3                                                deli clerk server cashier food prep order taker safeway grocery inc lodi
# 4                                                                                        cashier cristina green daly city

# %%
applicants.shape
# Out:
# (7037, 2)

# %% [markdown]
# ## **Recommender System**

# %% [markdown]
# Compute the **cosine similarity using TFIDF**

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
tfidf_applicants = tfidf_vectorizer.transform(applicants['corpus'])
cosine_similarity_tfidf = map(lambda job: cosine_similarity(tfidf_applicants, job), tfidf_jobid)
# We have a matrix, that for every one of the available jobs (84,090)
# we have a cosine similarity for every pontential employee (7,037)
scores = list(cosine_similarity_tfidf)

# %%
def get_topRecommendations(applicant_id=326, n_top=10, df_jobs=df_jobs, applicants=applicants, scores=scores):
    """
    Given a person in the form of applicant_id, return the top most suitable jobs based
    on TF-IDF vectorization of job tokens and applicant tokens.
    
    """

    applicant_ix = np.where(applicants['Applicant_ID'] == applicant_id)[0][0]

    
    # For every job, I need to look for the user im looking for
    # Identify a vector that keeps the job_ix, and score
    applicant_scores = list(sorted([(job_ix, job[applicant_ix][0]) for job_ix, job in enumerate(scores)],
                                  key=lambda job: job[1], reverse=True))[:n_top]
    
    # Extract the jobs based on the indices and their top scores
    jobs_ix = [job_ix for job_ix, _ in applicant_scores]
    jobs_scores = [score for _, score in applicant_scores]

    # Combine and return applicant-job information
    topRecommendations = df_jobs.iloc[jobs_ix]
    topRecommendations['score'] = jobs_scores
    topRecommendations['Applicant_ID'] = applicant_id
    topRecommendations = topRecommendations[['Applicant_ID', 'Job_ID', 'Title', 'score']]

    return topRecommendations

# %%
get_topRecommendations()
# Out:
#        Applicant_ID  Job_ID  \
# 77448           326  311213
# 13443           326  227065
# 3231            326  141831
# 76180           326  309945
# 40634           326  270171
# 6988            326  146511
# 69346           326  303112
# 40385           326  269922
# 10301           326  150882
# 63958           326  294684
#
#                                                                                       Title  \
# 77448                   Application UI Developer - Contract to Hire @ iTech Solutions, Inc.
# 13443                                                  iOS Developer @ Unied Software Group
# 3231                    Lead Java/J2EE Developer - Contract to Hire @ iTech Solutions, Inc.
# 76180                                        Java Software Engineer @ iTech Solutions, Inc.
# 40634       Senior Java Developer - Contract to Hire - Great Salary @ iTech Solutions, Inc.
# 6988                                          Medical Charge Entry Specialist @ Accountemps
# 69346                                                            Java Developer @ TransHire
# 40385  Entry Level Java Developer / Jr. Java Developer - Contract to Hire @ iTech Solutions
# 10301                                 Java Consultant - Mobile Apps Development @ Consultis
# 63958                                                             Java Developer @ Kavaliro
#
#           score
# 77448  0.283291
# 13443  0.267393
# 3231   0.245702
# 76180  0.243742
# 40634  0.238764
# 6988   0.234826
# 69346  0.230941
# 40385  0.227022
# 10301  0.210647
# 63958  0.209494

# %%
# Select a number of random applicants, get 5
np.random.seed(11)
random_applicants = np.random.choice(applicants['Applicant_ID'], 5, replace=True)
random_applicants
# Out:
# array([ 4483,  9318, 11685,  9729,  3110], dtype=int64)

# %%
for applicant_id in random_applicants:
    print(f'PRINTING Applicant_ID = {applicant_id}\'s first 100 corpus words:\n')
    corpus = ' '.join(applicants.query('Applicant_ID == @applicant_id').iloc[0]['corpus'].split(' ')[:100])
    corpus = '\n'.join(textwrap.wrap(corpus, 50))
    print(corpus, end='\n')


    display(get_topRecommendations(applicant_id))
    print('\n\n')
# Out:
# PRINTING Applicant_ID = 4483's first 100 corpus words:
#
#  cashier pizza hut pleasanton cashier server non
# alcoholic beverages food prep host server host
# receptionist cashier
#        Applicant_ID  Job_ID  \
# 84081          4483     734
# 84040          4483     506
# 72898          4483  306666
# 27514          4483  257044
# 21470          4483     251
# 84005          4483     397
# 48326          4483  277870
# 6991           4483  146514
# 84089          4483      92
# 40840          4483  270378
#
#                                                                                                                          Title  \
# 84081                                                                                                    Server @ Pizza Antica
# 84040                                                                                                  Server @ Faz Pleasanton
# 72898                                                                                  Cashiers @ Helpmates Staffing Services.
# 27514  Marketing Assistant/ Server/ Host - To $11/hr - Part Time and Evening Hours - Unique Market Research Firm @ Select S...
# 21470                                                                                                     Server @ Zach's Cafe
# 84005                                                                                                      Server @ Ringer Hut
# 48326                                                                                                 Food Service @ Six Flags
# 6991                                                                                               Billing Clerk @ Accountemps
# 84089                                                                                               Cashier @ Kazoo Restaurant
# 40840                                                                            Cashier @ Northern Virginia Community College
#
#           score
# 84081  0.363659
# 84040  0.320930
# 72898  0.305610
# 27514  0.302519
# 21470  0.284735
# 84005  0.283917
# 48326  0.283473
# 6991   0.281822
# 84089  0.272934
# 40840  0.264937
# PRINTING Applicant_ID = 9318's first 100 corpus words:
#
#  driver diamond transportation springfield provide
# door door transportation elderly persons
# disabilities collect fare check accuracy ats
# caregiver individual development inc washington
# provide daily care elderly persons disabilities
# cook clean feed bath dress cashier stock clerk
# maxway temple hill provide customer service
# operate cash register complete transactions
# accuracy stock merchandise keep clean neat work
# space cashier safeway washington provide customer
# service operate cash register complete
# transactions accuracy maintain clean neat work
# space
#        Applicant_ID  Job_ID  \
# 20244          9318  249772
# 33342          9318  262878
# 50492          9318  280035
# 72865          9318  306633
# 33813          9318  263349
# 58335          9318  287873
# 58331          9318  287869
# 39905          9318  269442
# 48517          9318  278061
# 23893          9318  253422
#
#                                                                      Title  \
# 20244    Cashier - Starbucks at Molly Pitcher Travel Plaza @ HMSHost - USA
# 33342                                     Cashier/Stock Clerk @ Lamps Plus
# 50492                                     Cashier/Stock Clerk @ Lamps Plus
# 72865             Store Clerk (Seasonal - Full Time) @ Castaways RV Resort
# 33813  Store Clerk (Seasonal - Full Time) @ Jellystone of Western New York
# 58335  Store Clerk (Seasonal - Full Time) @ Jellystone of Western New York
# 58331           Store Clerk (Seasonal - Part Time) @ Wagon Wheel RV Resort
# 39905           Store Clerk (Seasonal - Full Time) @ Wagon Wheel RV Resort
# 48517               Cashier I- 10-7PM @ Sodexo-  Kennesaw State University
# 23893                               Lead Cashier @ Nebraska Furniture Mart
#
#           score
# 20244  0.227087
# 33342  0.212054
# 50492  0.212054
# 72865  0.205718
# 33813  0.205006
# 58335  0.205006
# 58331  0.202474
# 39905  0.202421
# 48517  0.201931
# 23893  0.198548
# PRINTING Applicant_ID = 11685's first 100 corpus words:
#
# exam proctor need university downtown beacon hill
# staff group llc boston part time instructors
# massachusetts national safety council boston part
# time instructors massachusetts national safety
# council boston
#        Applicant_ID  Job_ID  \
# 52647         11685  282189
# 27666         11685  257196
# 79205         11685  314400
# 45605         11685  275148
# 55514         11685  285054
# 69945         11685  303711
# 62566         11685  293224
# 78549         11685  313745
# 55859         11685  285399
# 72720         11685  306488
#
#                                                                                                                         Title  \
# 52647                          Part Time Positions-Administrative Opportunities-Boston Area @ Beacon Hill Staffing Group, LLC
# 27666                                                                                                                     LPN
# 79205                                                     Receptionist Needed for Non-Profit in Downtown Boston! @ OfficeTeam
# 45605                                                                                                 File Clerk @ OfficeTeam
# 55514                                                                                     Front Desk Coordinator @ OfficeTeam
# 69945  Senior Sustainability Coordinator (Departmental Assistant) Auxiliary Enterprises @ University of Massachusetts Amherst
# 62566                                                            Driving Instructors @ Nationwide truck driver training group
# 78549                                                                     Software Engineer @ Beacon Hill Staffing Group, LLC
# 55859                                                              Administrative Assistant @ Beacon Hill Staffing Group, LLC
# 72720                                                                                                 File Clerk @ OfficeTeam
#
#           score
# 52647  0.324753
# 27666  0.294311
# 79205  0.258585
# 45605  0.249791
# 55514  0.240997
# 69945  0.240496
# 62566  0.239273
# 78549  0.231378
# 55859  0.225238
# 72720  0.222003
# PRINTING Applicant_ID = 9729's first 100 corpus words:
#
# seasonal wed sales stylist davids bridal lithonia
# seasonal wed sales stylist davids bridal lithonia
# paul mitchell school atlanta
#        Applicant_ID  Job_ID  \
# 18046          9729  247573
# 5562           9729  144886
# 81152          9729  316345
# 5309           9729  144633
# 5598           9729  144922
# 5513           9729  144837
# 5620           9729  144944
# 5339           9729  144663
# 5597           9729  144921
# 5782           9729  145106
#
#                                                                 Title  \
# 18046  Bridal Stylist Sales Consultant @ Jeanette's Bride 'N Boutique
# 5562                                    Seasonal CSR @ David's Bridal
# 81152                    Stylist Sales Consultant @ Impression Bridal
# 5309                  Seasonal Wedding Sales Stylist @ David's Bridal
# 5598                  Seasonal Wedding Sales Stylist @ David's Bridal
# 5513                  Seasonal Wedding Sales Stylist @ David's Bridal
# 5620                  Seasonal Wedding Sales Stylist @ David's Bridal
# 5339                  Seasonal Wedding Sales Stylist @ David's Bridal
# 5597                  Seasonal Wedding Sales Stylist @ David's Bridal
# 5782                  Seasonal Wedding Sales Stylist @ David's Bridal
#
#           score
# 18046  0.392162
# 5562   0.384417
# 81152  0.354339
# 5309   0.328224
# 5598   0.313780
# 5513   0.313622
# 5620   0.313572
# 5339   0.313561
# 5597   0.313494
# 5782   0.313494
# PRINTING Applicant_ID = 3110's first 100 corpus words:
#
#  pool cleaner beacon pool davie clean pool include
# clear debris pool water proper chemical balance
# mechanical inspections dishwasher customer service
# rep
#        Applicant_ID  Job_ID  \
# 65814          3110  296539
# 33825          3110  263361
# 77569          3110  311334
# 26192          3110  255723
# 79508          3110  314703
# 71085          3110  304853
# 71082          3110  304850
# 71088          3110  304856
# 79507          3110  314702
# 56171          3110  285711
#
#                                                               Title     score
# 65814               Pool Attendant (Seasonal - Part Time) @ Holiday  0.579091
# 33825             Pool Attendant (Seasonal - Part Time) @ West Glen  0.578873
# 77569  Pool Attendant (Seasonal - Part Time) @ East Village Estates  0.577535
# 26192                        Pool Attendant @ Country Hills Village  0.577524
# 79508           Pool Attendant (Seasonal - Part Time) @ Glen Laurel  0.577400
# 71085              Pool Attendant (Seasonal - Part Time) @ Lakeview  0.577214
# 71082              Pool Attendant (Seasonal - Part Time) @ Catalina  0.577134
# 71088          Pool Attendant (Seasonal - Part Time) @ Sherman Oaks  0.577116
# 79507         Pool Attendant (Seasonal - Part Time) @ Windham Hills  0.576907
# 56171      Pool Attendant (Seasonal - Part Time) @ Sycamore Village  0.576880
